# %% [markdown]
# # YOLOv5

# %%
import os
os.getcwd()
# Out:
# '/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes'

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10858, done.
# remote: Total 10858 (delta 0), reused 0 (delta 0), pack-reused 10858
# Receiving objects: 100% (10858/10858), 10.94 MiB | 9.31 MiB/s, done.
# Resolving deltas: 100% (7502/7502), done.

# %%
# %cd yolov5
# Out:
# /Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/yolov5

# %%
# !ls
# Out:
# CONTRIBUTING.md  data             requirements.txt utils
# Dockerfile       detect.py        runs             val.py
# LICENSE          export.py        setup.cfg        yolov5s.pt
# README.md        hubconf.py       train.py
# __pycache__      models           tutorial.ipynb

# %%
# !pip install -r requirements.txt  # install
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (3.5.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.22.2)
# Requirement already satisfied: opencv-python>=4.1.2 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (4.5.5.62)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (9.0.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.7.3)
# Requirement already satisfied: torch>=1.7.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.10.2)
# Requirement already satisfied: torchvision>=0.8.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.11.3)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (4.62.3)
# Requirement already satisfied: tensorboard>=2.4.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (2.8.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (1.4.0)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.11.2)
# Requirement already satisfied: thop in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.0.31.post2005241907)
# Requirement already satisfied: cycler>=0.10 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (4.28.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.11)
# Requirement already satisfied: typing-extensions in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (4.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.6.0)
# Requirement already satisfied: protobuf>=3.6.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.19.4)
# Requirement already satisfied: wheel>=0.26 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.0.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (60.7.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.43.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2021.3)
# Requirement already satisfied: six in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.10.1)
# Requirement already satisfied: zipp>=0.5 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.2.0)

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train
# Out:
#       <iframe id="tensorboard-frame-832e797c17775e40" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-832e797c17775e40");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 4 --epochs 3 --data data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=3, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-235-ge1a6a0b torch 1.10.2 CPU
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=31
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     97092  models.yolo.Detect                      [31, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 270 layers, 7103236 parameters, 7103236 gradients, 16.1 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# train: Scanning '/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/datas
# train: Caching images (4.1GB ram): 100%|███| 4454/4454 [00:10<00:00, 433.06it/s]
# val: Scanning '/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/dataset
# val: Caching images (0.2GB ram):  37%|██▌    | 235/639 [00:01<00:01, 204.82it/s]Corrupt JPEG data: premature end of data segment
# val: Caching images (0.6GB ram): 100%|███████| 639/639 [00:03<00:00, 210.15it/s]
# Plotting labels to runs/train/exp6/labels.jpg...
#
# AutoAnchor: 5.81 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/train/exp6
# Starting training for 3 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   0%|          | 0/1114 [00:00<?, ?it/s]                                        /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1276   0.02915   0.09645         8       640:   0%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1269    0.0288   0.09354         7       640:   0%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1274   0.02908   0.09355         7       640:   0%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G     0.127   0.02911   0.09298         6       640:   0%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1271    0.0285    0.0926         4       640:   0%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1269   0.02808   0.09239         4       640:   1%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1258   0.02777   0.09237         3       640:   1%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1234   0.02802    0.0905         5       640:   1%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1234   0.02833   0.09046         9       640:   1%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1231    0.0285   0.09074         8       640:   1%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1237   0.02834   0.09129         6       640:   1%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1235    0.0287   0.09119        11       640:   1%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1232   0.02881   0.09089         7       640:   1%|   /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1232   0.02854   0.09063         3       640:   1%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1228   0.02866   0.09036         7       640:   1%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1225    0.0291   0.09036        12       640:   1%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G     0.123   0.02908   0.09056         9       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1231   0.02902   0.09059         7       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1232   0.02886   0.09085         7       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1229   0.02881     0.091         6       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1232   0.02874   0.09098        11       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1232   0.02874   0.09098         9       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1229   0.02862    0.0909         5       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1225    0.0287   0.09087         9       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1225   0.02883   0.09077        12       640:   2%|▏  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.
640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1158   0.02628    0.0899         6       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1157   0.02627   0.08991         7       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1155   0.02629   0.08991         8       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1156   0.02626   0.08985        10       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1156   0.02622   0.08983         5       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1155    0.0262   0.08981         6       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1153   0.02612   0.08976         3       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1153   0.02616   0.08976        11       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1151   0.02617   0.08971         8       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G     0.115   0.02619   0.08967         8       640:  10%|█  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1148   0.02616   0.08967         4       640:  10%|█  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1148   0.02612   0.08966         6       640:  10%|█  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1147   0.02608   0.08961         4       640:  10%|█  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1146   0.02608    0.0896         7       640:  10%|█  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1144   0.02601   0.08955         2       640:  11%|█  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        0/2        0G    0.1143   0.02596   0.08947         5       640:  11%|█  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# ...
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G    0.0465   0.01442    0.0832         5       640:   6%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04654   0.01444    0.0832        10       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04647   0.01442   0.08321         5       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04659   0.01433   0.08313         5       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04655   0.01442   0.08312        12       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04656   0.01439   0.08313         8       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04653   0.01442   0.08307         7       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04644   0.01447   0.08304         8       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04643   0.01446   0.08305         6       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04632   0.01437     0.083         3       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04621   0.01435   0.08295         5       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04604   0.01433   0.08294         5       640:   7%|▋  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04594    0.0144   0.08294        10       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04592   0.01438   0.08291         8       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04599   0.01436   0.08295         6       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04592    0.0144   0.08298         9       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04595   0.01438   0.08296         6       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04604   0.01433   0.08299         6       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04604   0.01436   0.08303         8       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G     0.046   0.01436   0.08301         7       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04597   0.01437   0.08298         8       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04609   0.01437   0.08296         7       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04596   0.01438   0.08295         7       640:   8%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04607   0.01433   0.08293         4       640:   9%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G    0.0461   0.01431   0.08286         6       640:   9%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04602   0.01429   0.08293         5       640:   9%|▊  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04595   0.01434   0.08293        10       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04585   0.01433   0.08296         6       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04576   0.01431   0.08292         6       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04567   0.01434   0.08293         8       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04567   0.01431   0.08288         6       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04564   0.01427   0.08293         5       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G    0.0456   0.01423   0.08293         4       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04557   0.01417   0.08295         3       640:   9%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04558   0.01414   0.08294         4       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04558   0.01409   0.08295         4       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04561   0.01407     0.083         7       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#        1/2        0G   0.04572   0.01404     0.083         5       640:  10%|▉  /Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# ^C
#        1/2        0G   0.04572   0.01404     0.083         5       640:  10%|▉
# Traceback (most recent call last):
#   File "/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/yolov5/train.py", line 638, in <module>
#     main(opt)
#   File "/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/yolov5/train.py", line 535, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/yolov5/train.py", line 329, in train
#     pred = model(imgs)  # forward
#   File "/Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/yolov5/models/yolo.py", line 126, in forward
#     return self._forward_once(x, profile, visualize)  # single-scale inference, train
#   File "/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/yolov5/models/yolo.py", line 149, in _forward_once
#     x = m(x)  # run
#   File "/Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/yolov5/models/common.py", line 139, in forward
#     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), dim=1))
#   File "/Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/sankeerthana/Documents/NTU/YEAR_3/CZ3004_MDP/codes/yolov5/models/common.py", line 47, in forward
#     return self.act(self.bn(self.conv(x)))
#   File "/Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/nn/modules/conv.py", line 446, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/Users/sankeerthana/miniforge3/envs/mdp/lib/python3.9/site-packages/torch/nn/modules/conv.py", line 442, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
# KeyboardInterrupt
