# %% [markdown]
# # CZ4041 - Course Project - Taxi Fare

# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sb
import datetime as dt
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
from math import *
import json

# %% [markdown]
# ## Loading the Datasets

# %%
df_train = pd.read_csv("train.csv")

# %%
#displaying the first 5 rows of train 
df_train.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
#shape of df_train
print("df_train shape:",df_train.shape)
# Out:
# df_train shape: (55423856, 8)

# %%
columns = df_train.columns
print("Columns:", list(columns))
print("Length of Columns:", len(columns))
# Out:
# Columns: ['key', 'fare_amount', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count']
# Length of Columns: 8

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Deleting the rows where pickup/dropoff_datetime, pickup/dropoff_longitude, pickup/dropoff_latitude are 0

# %%
df_train_copy = df_train.copy()
train_wo_zeros = df_train_copy[(df_train_copy.pickup_datetime != 0) & (df_train_copy.pickup_latitude != 0) & (df_train_copy.dropoff_latitude != 0) & (df_train_copy.pickup_longitude != 0) & (df_train_copy.dropoff_longitude != 0)]
train_wo_zeros
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 0           2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1           2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2          2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3           2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4         2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                                 ...          ...                      ...
# 55423851   2014-03-15 03:28:00.00000070         14.0  2014-03-15 03:28:00 UTC
# 55423852    2009-03-24 20:46:20.0000002          4.2  2009-03-24 20:46:20 UTC
# 55423853    2011-04-02 22:04:24.0000004         14.1  2011-04-02 22:04:24 UTC
# 55423854    2011-10-26 05:57:51.0000002         28.9  2011-10-26 05:57:51 UTC
# 55423855   2014-12-12 11:33:00.00000015          7.5  2014-12-12 11:33:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 55423851        -74.005272        40.740027         -73.963280
# 55423852        -73.957784        40.765530         -73.951640
# 55423853        -73.970505        40.752325         -73.960537
# 55423854        -73.980901        40.764629         -73.870605
# 55423855        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count
# 0                40.712278                1
# 1                40.782004                1
# 2                40.750562                2
# 3                40.758092                1
# 4                40.783762                1
# ...                    ...              ...
# 55423851         40.762555                1
# 55423852         40.773959                1
# 55423853         40.797342                1
# 55423854         40.773963                1
# 55423855         40.783313                1
#
# [54319366 rows x 8 columns]

# %%
print("Shape of df initially:", df_train.shape)
print("Shape after removing rows with 4 0s:", train_wo_zeros.shape)
print("Number of rows with 4 0s:", df_train.shape[0] - train_wo_zeros.shape[0])
# Out:
# Shape of df initially: (55423856, 8)
# Shape after removing rows with 4 0s: (54319366, 8)
# Number of rows with 4 0s: 1104490

# %%
#Resetting the index, inplace to make sure the indexes are all correct
train_wo_zeros.reset_index(inplace=True)
train_wo_zeros.tail()
# Out:
#              index                           key  fare_amount  \
# 54319361  55423851  2014-03-15 03:28:00.00000070         14.0
# 54319362  55423852   2009-03-24 20:46:20.0000002          4.2
# 54319363  55423853   2011-04-02 22:04:24.0000004         14.1
# 54319364  55423854   2011-10-26 05:57:51.0000002         28.9
# 54319365  55423855  2014-12-12 11:33:00.00000015          7.5
#
#                   pickup_datetime  pickup_longitude  pickup_latitude  \
# 54319361  2014-03-15 03:28:00 UTC        -74.005272        40.740027
# 54319362  2009-03-24 20:46:20 UTC        -73.957784        40.765530
# 54319363  2011-04-02 22:04:24 UTC        -73.970505        40.752325
# 54319364  2011-10-26 05:57:51 UTC        -73.980901        40.764629
# 54319365  2014-12-12 11:33:00 UTC        -73.969722        40.797668
#
#           dropoff_longitude  dropoff_latitude  passenger_count
# 54319361         -73.963280         40.762555                1
# 54319362         -73.951640         40.773959                1
# 54319363         -73.960537         40.797342                1
# 54319364         -73.870605         40.773963                1
# 54319365         -73.970885         40.783313                1

# %% [markdown]
# ### Dealing with Null Values

# %%
#checking which columns have NaN values
train_wo_zeros.isnull().any()
# Out:
# index                False
# key                  False
# fare_amount          False
# pickup_datetime      False
# pickup_longitude     False
# pickup_latitude      False
# dropoff_longitude     True
# dropoff_latitude      True
# passenger_count      False
# dtype: bool

# %% [markdown]
# Therefore, dropoff_longitude and dropoff_latitude have NaN in them.

# %%
nan_rows_lat = train_wo_zeros[train_wo_zeros['dropoff_latitude'].isnull()]
nan_rows_long = train_wo_zeros[train_wo_zeros['dropoff_longitude'].isnull()]

print("nan_rows_lat:", nan_rows_lat)
print("# of rows:", nan_rows_lat.shape[0])

print("nan_rows_long:", nan_rows_long)
print("# of rows:", nan_rows_long.shape[0])
# Out:
# nan_rows_lat:              index                           key  fare_amount  \
# 117801      120227  2012-12-11 12:57:00.00000013        12.50
# 240885      245696   2013-03-21 18:07:07.0000001        86.50
# 333842      340533  2012-12-11 12:50:52.00000010        27.50
# 419621      428108   2011-09-08 09:12:52.0000001        11.80
# 514475      524834   2011-09-25 23:01:12.0000005        14.76
# ...            ...                           ...          ...
# 53492512  54580245   2012-11-16 17:44:07.0000002        44.00
# 53589436  54679078   2011-11-07 08:14:05.0000004        13.42
# 53803790  54897759   2012-12-11 12:51:34.0000002         8.50
# 53869393  54964682   2011-10-04 02:39:52.0000001        12.36
# 54152201  55253379   2013-10-10 08:20:25.0000005         6.00
#
#                   pickup_datetime  pickup_longitude  pickup_latitude  \
# 117801    2012-12-11 12:57:00 UTC        -73.992760        40.743098
# 240885    2013-03-21 18:07:07 UTC        -73.991572        40.740591
# 333842    2012-12-11 12:50:52 UTC        -73.979639        40.784742
# 419621    2011-09-08 09:12:52 UTC        -73.987041        40.751542
# 514475    2011-09-25 23:01:12 UTC        -73.985374        40.768518
# ...                           ...               ...              ...
# 53492512  2012-11-16 17:44:07 UTC        -73.975032        40.782760
# 53589436  2011-11-07 08:14:05 UTC        -74.009559        40.712710
# 53803790  2012-12-11 12:51:34 UTC        -73.960464        40.776124
# 53869393  2011-10-04 02:39:52 UTC        -73.999355        40.754399
# 54152201  2013-10-10 08:20:25 UTC        -73.993832        40.746390
#
#           dropoff_longitude  dropoff_latitude  passenger_count
# 117801                  NaN               NaN                0
# 240885                  NaN               NaN                0
# 333842                  NaN               NaN                0
# 419621                  NaN               NaN                0
# 514475                  NaN               NaN                0
# ...                     ...               ...              ...
# 53492512                NaN               NaN                0
# 53589436                NaN               NaN                0
# 53803790                NaN               NaN                0
# 53869393                NaN               NaN                0
# 54152201                NaN               NaN                0
#
# [335 rows x 9 columns]
# # of rows: 335
# nan_rows_long:              index                           key  fare_amount  \
# 117801      120227  2012-12-11 12:57:00.00000013        12.50
# 240885      245696   2013-03-21 18:07:07.0000001        86.50
# 333842      340533  2012-12-11 12:50:52.00000010        27.50
# 419621      428108   2011-09-08 09:12:52.0000001        11.80
# 514475      524834   2011-09-25 23:01:12.0000005        14.76
# ...            ...                           ...          ...
# 53492512  54580245   2012-11-16 17:44:07.0000002        44.00
# 53589436  54679078   2011-11-07 08:14:05.0000004        13.42
# 53803790  54897759   2012-12-11 12:51:34.0000002         8.50
# 53869393  54964682   2011-10-04 02:39:52.0000001        12.36
# 54152201  55253379   2013-10-10 08:20:25.0000005         6.00
#
#                   pickup_datetime  pickup_longitude  pickup_latitude  \
# 117801    2012-12-11 12:57:00 UTC        -73.992760        40.743098
# 240885    2013-03-21 18:07:07 UTC        -73.991572        40.740591
# 333842    2012-12-11 12:50:52 UTC        -73.979639        40.784742
# 419621    2011-09-08 09:12:52 UTC        -73.987041        40.751542
# 514475    2011-09-25 23:01:12 UTC        -73.985374        40.768518
# ...                           ...               ...              ...
# 53492512  2012-11-16 17:44:07 UTC        -73.975032        40.782760
# 53589436  2011-11-07 08:14:05 UTC        -74.009559        40.712710
# 53803790  2012-12-11 12:51:34 UTC        -73.960464        40.776124
# 53869393  2011-10-04 02:39:52 UTC        -73.999355        40.754399
# 54152201  2013-10-10 08:20:25 UTC        -73.993832        40.746390
#
#           dropoff_longitude  dropoff_latitude  passenger_count
# 117801                  NaN               NaN                0
# 240885                  NaN               NaN                0
# 333842                  NaN               NaN                0
# 419621                  NaN               NaN                0
# 514475                  NaN               NaN                0
# ...                     ...               ...              ...
# 53492512                NaN               NaN                0
# 53589436                NaN               NaN                0
# 53803790                NaN               NaN                0
# 53869393                NaN               NaN                0
# 54152201                NaN               NaN                0
#
# [335 rows x 9 columns]
# # of rows: 335

# %%
nan_rows_lat_idx = list(nan_rows_lat.index)
nan_rows_long_idx = list(nan_rows_long.index)

# %%
#viewing one particular row to analyse it further
train_wo_zeros.iloc[nan_rows_lat_idx[0]]
# Out:
# index                                      120227
# key                  2012-12-11 12:57:00.00000013
# fare_amount                                  12.5
# pickup_datetime           2012-12-11 12:57:00 UTC
# pickup_longitude                        -73.99276
# pickup_latitude                         40.743098
# dropoff_longitude                             NaN
# dropoff_latitude                              NaN
# passenger_count                                 0
# Name: 117801, dtype: object

# %%
#checking if both nan_rows_lat_idx and nan_rows_long_idx are the same
if nan_rows_lat_idx == nan_rows_long_idx:
    print("Both the Lists are identical! Therefore, just using one list will do!")
else:
    print("Both lists are not identical! Hence, we need to account for repeated row indices!")
# Out:
# Both the Lists are identical! Therefore, just using one list will do!

# %% [markdown]
# The lists nan_rows_lat_idx and nan_rows_long_idx contain the indices of the rows that contain both dropoff_latitude and dropoff_longitude as NaN. There is no case where either one of them is a NaN and the other one if a valid value, this is because, form the test above, both the lists are identical, whoch means the row indices are exact same, hence, there exists only the case where either both of the column's vlaues are NaN or None of it. Hence, we will just be using the nan_rows_lat_idx to remove the rows that contain NaN.

# %%
#creating a copy of the existing df
train_wo_nan = train_wo_zeros.copy()

# %%
#dropping the rows with NaN
train_wo_nan.drop(axis=0, index=nan_rows_lat_idx,inplace=True)

#resetting the index
train_wo_nan.reset_index(inplace=True)

# %%
#Math to check 
NUM_NAN_ROWS = len(nan_rows_lat_idx)

print("Number of rows before dropping NaN rows:", train_wo_zeros.shape[0])

if train_wo_zeros.shape[0] - train_wo_nan.shape[0] == NUM_NAN_ROWS:
    print("Successfully dropped ", NUM_NAN_ROWS, "rows!")
    print("Number of rows in train_wo_nan:", train_wo_nan.shape[0])
else:
    print("Error! Dropped Wrong Number of Rows!")
# Out:
# Number of rows before dropping NaN rows: 54319366
# Successfully dropped  335 rows!
# Number of rows in train_wo_nan: 54319031

# %%
#removing columns that were unintentionally added at the backend 
train_wo_nan.drop(['level_0','index'], axis = 1, inplace=True)

# %%
train_wo_nan
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 0           2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1           2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2          2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3           2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4         2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                                 ...          ...                      ...
# 54319026   2014-03-15 03:28:00.00000070         14.0  2014-03-15 03:28:00 UTC
# 54319027    2009-03-24 20:46:20.0000002          4.2  2009-03-24 20:46:20 UTC
# 54319028    2011-04-02 22:04:24.0000004         14.1  2011-04-02 22:04:24 UTC
# 54319029    2011-10-26 05:57:51.0000002         28.9  2011-10-26 05:57:51 UTC
# 54319030   2014-12-12 11:33:00.00000015          7.5  2014-12-12 11:33:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54319026        -74.005272        40.740027         -73.963280
# 54319027        -73.957784        40.765530         -73.951640
# 54319028        -73.970505        40.752325         -73.960537
# 54319029        -73.980901        40.764629         -73.870605
# 54319030        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count
# 0                40.712278                1
# 1                40.782004                1
# 2                40.750562                2
# 3                40.758092                1
# 4                40.783762                1
# ...                    ...              ...
# 54319026         40.762555                1
# 54319027         40.773959                1
# 54319028         40.797342                1
# 54319029         40.773963                1
# 54319030         40.783313                1
#
# [54319031 rows x 8 columns]

# %%
#cross-checking if there are any NaN values at all
train_wo_nan.isnull().any()
# Out:
# key                  False
# fare_amount          False
# pickup_datetime      False
# pickup_longitude     False
# pickup_latitude      False
# dropoff_longitude    False
# dropoff_latitude     False
# passenger_count      False
# dtype: bool

# %% [markdown]
# ### Dealing with passenger_count == 0

# %%
#checking if there are any rows where the passenger_count == 0
(train_wo_nan['passenger_count'] == 0).any()
# Out:
# True

# %% [markdown]
# Since the output is True, it means that there are rows where the passenger_count == 0. Let's look deeper into this!

# %%
count = (train_wo_nan['passenger_count'] == 0).sum()
print("Number of 0s in passenger_count:", count)
# Out:
# Number of 0s in passenger_count: 190853

# %%
zero_values = train_wo_nan[train_wo_nan['passenger_count'] == 0]
zero_values
# Out:
#                                    key  fare_amount          pickup_datetime  \
# 307       2015-06-02 23:16:15.00000012         34.0  2015-06-02 23:16:15 UTC
# 552        2012-01-28 21:33:18.0000002          4.9  2012-01-28 21:33:18 UTC
# 662        2012-02-27 07:24:20.0000003          6.5  2012-02-27 07:24:20 UTC
# 1135       2011-05-25 23:58:48.0000001         13.3  2011-05-25 23:58:48 UTC
# 1894       2011-10-23 11:09:28.0000001         10.1  2011-10-23 11:09:28 UTC
# ...                                ...          ...                      ...
# 54317488   2011-07-31 15:25:05.0000004         17.7  2011-07-31 15:25:05 UTC
# 54318106   2011-10-19 18:46:09.0000001         11.7  2011-10-19 18:46:09 UTC
# 54318152   2012-02-08 23:52:37.0000001          6.9  2012-02-08 23:52:37 UTC
# 54318172   2011-10-21 10:21:32.0000003          6.5  2011-10-21 10:21:32 UTC
# 54318513   2011-08-17 17:17:35.0000003          4.5  2011-08-17 17:17:35 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 307             -73.974899        40.751095         -73.908546
# 552             -73.955322        40.782840         -73.955797
# 662             -73.983397        40.738183         -73.971395
# 1135            -73.998360        40.740348         -73.946455
# 1894            -73.971400        40.795000         -73.967900
# ...                    ...              ...                ...
# 54317488        -73.975100        40.681000         -73.980300
# 54318106        -73.985200        40.755900         -73.972000
# 54318152        -74.004172        40.751831         -73.994318
# 54318172        -73.982300        40.768100         -73.968200
# 54318513        -73.956200        40.778900         -73.970500
#
#           dropoff_latitude  passenger_count
# 307              40.881878                0
# 552              40.773673                0
# 662              40.758023                0
# 1135             40.777348                0
# 1894             40.768600                0
# ...                    ...              ...
# 54317488         40.742400                0
# 54318106         40.764700                0
# 54318152         40.738853                0
# 54318172         40.760400                0
# 54318513         40.783900                0
#
# [190853 rows x 8 columns]

# %%
#Obtaining the indices of rows where passenger_count == 0 and converting it into a list
zero_values_idx = list(zero_values.index)

# %%
pass_count_dropped = train_wo_nan.copy()

# %%
#dropping the rows
pass_count_dropped.drop(axis=0, index=zero_values_idx,inplace=True)

#resetting the index
pass_count_dropped.reset_index(inplace=True)

pass_count_dropped
# Out:
#              index                            key  fare_amount  \
# 0                0    2009-06-15 17:26:21.0000001          4.5
# 1                1    2010-01-05 16:52:16.0000002         16.9
# 2                2   2011-08-18 00:35:00.00000049          5.7
# 3                3    2012-04-21 04:30:42.0000001          7.7
# 4                4  2010-03-09 07:51:00.000000135          5.3
# ...            ...                            ...          ...
# 54128173  54319026   2014-03-15 03:28:00.00000070         14.0
# 54128174  54319027    2009-03-24 20:46:20.0000002          4.2
# 54128175  54319028    2011-04-02 22:04:24.0000004         14.1
# 54128176  54319029    2011-10-26 05:57:51.0000002         28.9
# 54128177  54319030   2014-12-12 11:33:00.00000015          7.5
#
#                   pickup_datetime  pickup_longitude  pickup_latitude  \
# 0         2009-06-15 17:26:21 UTC        -73.844311        40.721319
# 1         2010-01-05 16:52:16 UTC        -74.016048        40.711303
# 2         2011-08-18 00:35:00 UTC        -73.982738        40.761270
# 3         2012-04-21 04:30:42 UTC        -73.987130        40.733143
# 4         2010-03-09 07:51:00 UTC        -73.968095        40.768008
# ...                           ...               ...              ...
# 54128173  2014-03-15 03:28:00 UTC        -74.005272        40.740027
# 54128174  2009-03-24 20:46:20 UTC        -73.957784        40.765530
# 54128175  2011-04-02 22:04:24 UTC        -73.970505        40.752325
# 54128176  2011-10-26 05:57:51 UTC        -73.980901        40.764629
# 54128177  2014-12-12 11:33:00 UTC        -73.969722        40.797668
#
#           dropoff_longitude  dropoff_latitude  passenger_count
# 0                -73.841610         40.712278                1
# 1                -73.979268         40.782004                1
# 2                -73.991242         40.750562                2
# 3                -73.991567         40.758092                1
# 4                -73.956655         40.783762                1
# ...                     ...               ...              ...
# 54128173         -73.963280         40.762555                1
# 54128174         -73.951640         40.773959                1
# 54128175         -73.960537         40.797342                1
# 54128176         -73.870605         40.773963                1
# 54128177         -73.970885         40.783313                1
#
# [54128178 rows x 9 columns]

# %%
NUM_PASS_COUNT_0 = len(zero_values_idx)
print("Number of rows before dropping passenger_count == 0 rows:", train_wo_nan.shape[0])

if (train_wo_nan.shape[0] - pass_count_dropped.shape[0] == NUM_PASS_COUNT_0):
    print("Successfully dropped ", NUM_PASS_COUNT_0, "rows!")
    print("Number of rows in pass_count_dropped:", pass_count_dropped.shape[0])
else:
    print("Error! Dropped Wrong Number of Rows!")
# Out:
# Number of rows before dropping passenger_count == 0 rows: 54319031
# Successfully dropped  190853 rows!
# Number of rows in pass_count_dropped: 54128178

# %%
#Dropping unnecessary columns from the df 
pass_count_dropped.drop(['index'], axis = 1, inplace=True)
pass_count_dropped
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 0           2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1           2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2          2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3           2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4         2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                                 ...          ...                      ...
# 54128173   2014-03-15 03:28:00.00000070         14.0  2014-03-15 03:28:00 UTC
# 54128174    2009-03-24 20:46:20.0000002          4.2  2009-03-24 20:46:20 UTC
# 54128175    2011-04-02 22:04:24.0000004         14.1  2011-04-02 22:04:24 UTC
# 54128176    2011-10-26 05:57:51.0000002         28.9  2011-10-26 05:57:51 UTC
# 54128177   2014-12-12 11:33:00.00000015          7.5  2014-12-12 11:33:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54128173        -74.005272        40.740027         -73.963280
# 54128174        -73.957784        40.765530         -73.951640
# 54128175        -73.970505        40.752325         -73.960537
# 54128176        -73.980901        40.764629         -73.870605
# 54128177        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count
# 0                40.712278                1
# 1                40.782004                1
# 2                40.750562                2
# 3                40.758092                1
# 4                40.783762                1
# ...                    ...              ...
# 54128173         40.762555                1
# 54128174         40.773959                1
# 54128175         40.797342                1
# 54128176         40.773963                1
# 54128177         40.783313                1
#
# [54128178 rows x 8 columns]

# %%
#checking if passenger_count == 0 still exists
(pass_count_dropped['passenger_count'] == 0).any()
# Out:
# False

# %% [markdown]
# Since, the output is False, it means that there are no more rows where passenger_count == 0.

# %% [markdown]
# ### Visualising Passenger Count

# %% [markdown]
# We would like to visualise the distribution of passenger_count to check if there are any logical discrepancies. According to this source, by law an NYC Taxi is allowed to carry only 4 passengers and 5 passengers, if it is a 5 seater car. Passenger Count of greater than 5 is only allowed if children aged 7 or above are seated on the laps of the adult passenger.
#
# Hence, if the maximum number of adults seated is 5, then the maximum number of passengers in a taxi will be 5 + 5 = 10, assuming that each adult seated has a child he/she is holding onto.
#
# Hence, to ensure that this logic is not violated, we aim to visualise the distribution of the passenger_count variable and remove rows that contain values gretaer than 10.
#
# Link: https://www.google.com/urlsa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiew7PRucj2AhUjSWwGHZjiD_QQFnoECAsQAw&url=https%3A%2F%2Fwww1.nyc.gov%2Fsite%2Ftlc%2Fpassengers%2Fpassenger-frequently-askedquestions.page&usg=AOvVaw0lJJHgeBfD9Fi_4wir5Bgl

# %%
#extracting only the passeneger_count variable as a dataframe
passenger_count = pass_count_dropped[['passenger_count']]

print(type(passenger_count))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#analysing the inputs in the passenger_count column
passenger_count.value_counts()
# Out:
# passenger_count
# 1                  37560913
# 2                   8022344
# 5                   3848449
# 3                   2386087
# 4                   1156834
# 6                   1153482
# 208                      25
# 9                        21
# 7                        13
# 8                         7
# 129                       2
# 34                        1
# dtype: int64

# %%
#Plotting a Countplot
sb.set_theme(style="darkgrid")
ax = sb.countplot(x="passenger_count",data=passenger_count)

# %% [markdown]
# As we can see, majority of the records have only 1 passenger. However, there seem to be records that have 34, 129 and 208 passengers in the taxi. This is not logically possible, hence, this rows will be removed.

# %%
final_pass_count = pass_count_dropped.copy()

# %%
illogical_rows= final_pass_count[(final_pass_count['passenger_count'] == 34) | (final_pass_count['passenger_count'] == 129) | (final_pass_count['passenger_count'] == 208)]
illogical_rows
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 3034937   2009-05-12 14:50:00.000000175          2.7  2009-05-12 14:50:00 UTC
# 3246166   2011-08-27 01:24:00.000000168          8.5  2011-08-27 01:24:00 UTC
# 4328865    2009-05-11 13:56:00.00000088         11.1  2009-05-11 13:56:00 UTC
# 6837485   2009-02-26 08:29:00.000000201          2.7  2009-02-26 08:29:00 UTC
# 11006578   2010-11-02 11:54:00.00000099          3.3  2010-11-02 11:54:00 UTC
# 13641604   2010-03-23 13:22:00.00000022          7.1  2010-03-23 13:22:00 UTC
# 17540626  2010-09-21 17:19:00.000000179         13.3  2010-09-21 17:19:00 UTC
# 20040214   2010-12-29 12:33:00.00000081          3.3  2010-12-29 12:33:00 UTC
# 21206294   2009-07-06 22:53:00.00000013          2.7  2009-07-06 22:53:00 UTC
# 28359772   2009-05-04 23:08:00.00000058          7.1  2009-05-04 23:08:00 UTC
# 29021690   2009-05-12 14:59:00.00000051          2.7  2009-05-12 14:59:00 UTC
# 29799589   2009-03-17 14:22:00.00000075          2.9  2009-03-17 14:22:00 UTC
# 31051095  2010-11-02 14:44:00.000000212          3.3  2010-11-02 14:44:00 UTC
# 31151963   2009-05-15 05:52:00.00000014         18.5  2009-05-15 05:52:00 UTC
# 33914377  2010-12-15 12:03:00.000000181          3.3  2010-12-15 12:03:00 UTC
# 35054129    2010-12-28 08:20:00.0000001         11.7  2010-12-28 08:20:00 UTC
# 42102814   2009-03-11 09:32:00.00000094          2.7  2009-03-11 09:32:00 UTC
# 42441547  2009-06-23 23:05:00.000000120          2.9  2009-06-23 23:05:00 UTC
# 42582869    2009-05-26 14:58:00.0000002          2.9  2009-05-26 14:58:00 UTC
# 43459797  2009-07-23 17:05:00.000000153          9.3  2009-07-23 17:05:00 UTC
# 44674768   2010-12-21 06:27:00.00000039          3.5  2010-12-21 06:27:00 UTC
# Out:
#              index                            key  fare_amount  \
# 0                0    2009-06-15 17:26:21.0000001          4.5
# 1                1    2010-01-05 16:52:16.0000002         16.9
# 2                2   2011-08-18 00:35:00.00000049          5.7
# 3                3    2012-04-21 04:30:42.0000001          7.7
# 4                4  2010-03-09 07:51:00.000000135          5.3
# ...            ...                            ...          ...
# 54128145  54128173   2014-03-15 03:28:00.00000070         14.0
# 54128146  54128174    2009-03-24 20:46:20.0000002          4.2
# 54128147  54128175    2011-04-02 22:04:24.0000004         14.1
# 54128148  54128176    2011-10-26 05:57:51.0000002         28.9
# 54128149  54128177   2014-12-12 11:33:00.00000015          7.5
#
#                   pickup_datetime  pickup_longitude  pickup_latitude  \
# 0         2009-06-15 17:26:21 UTC        -73.844311        40.721319
# 1         2010-01-05 16:52:16 UTC        -74.016048        40.711303
# 2         2011-08-18 00:35:00 UTC        -73.982738        40.761270
# 3         2012-04-21 04:30:42 UTC        -73.987130        40.733143
# 4         2010-03-09 07:51:00 UTC        -73.968095        40.768008
# ...                           ...               ...              ...
# 54128145  2014-03-15 03:28:00 UTC        -74.005272        40.740027
# 54128146  2009-03-24 20:46:20 UTC        -73.957784        40.765530
# 54128147  2011-04-02 22:04:24 UTC        -73.970505        40.752325
# 54128148  2011-10-26 05:57:51 UTC        -73.980901        40.764629
# 54128149  2014-12-12 11:33:00 UTC        -73.969722        40.797668
#
#           dropoff_longitude  dropoff_latitude  passenger_count
# 0                -73.841610         40.712278                1
# 1                -73.979268         40.782004                1
# 2                -73.991242         40.750562                2
# 3                -73.991567         40.758092                1
# 4                -73.956655         40.783762                1
# ...                     ...               ...              ...
# 54128145         -73.963280         40.762555                1
# 54128146         -73.951640         40.773959                1
# 54128147         -73.960537         40.797342                1
# 54128148         -73.870605         40.773963                1
# 54128149         -73.970885         40.783313                1
#
# [54128150 rows x 9 columns]

# %%
print("Number of rows before dropping passenger_count == 34,129,208 rows:", pass_count_dropped.shape[0])

if (pass_count_dropped.shape[0] - final_pass_count.shape[0] == NUM_ILLOGICAL_ROWS):
    print("Successfully dropped ", NUM_ILLOGICAL_ROWS, "rows!")
    print("Number of rows in final_pass_count:", final_pass_count.shape[0])
else:
    print("Error! Dropped Wrong Number of Rows!")
# Out:
# Number of rows before dropping passenger_count == 34,129,208 rows: 54128178
# Successfully dropped  28 rows!
# Number of rows in final_pass_count: 54128150

# %%
#Dropping unnecessary columns from the df 
final_pass_count.drop(['index'], axis = 1, inplace=True)
final_pass_count
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 0           2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1           2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2          2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3           2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4         2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                                 ...          ...                      ...
# 54128145   2014-03-15 03:28:00.00000070         14.0  2014-03-15 03:28:00 UTC
# 54128146    2009-03-24 20:46:20.0000002          4.2  2009-03-24 20:46:20 UTC
# 54128147    2011-04-02 22:04:24.0000004         14.1  2011-04-02 22:04:24 UTC
# 54128148    2011-10-26 05:57:51.0000002         28.9  2011-10-26 05:57:51 UTC
# 54128149   2014-12-12 11:33:00.00000015          7.5  2014-12-12 11:33:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54128145        -74.005272        40.740027         -73.963280
# 54128146        -73.957784        40.765530         -73.951640
# 54128147        -73.970505        40.752325         -73.960537
# 54128148        -73.980901        40.764629         -73.870605
# 54128149        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count
# 0                40.712278                1
# 1                40.782004                1
# 2                40.750562                2
# 3                40.758092                1
# 4                40.783762                1
# ...                    ...              ...
# 54128145         40.762555                1
# 54128146         40.773959                1
# 54128147         40.797342                1
# 54128148         40.773963                1
# 54128149         40.783313                1
#
# [54128150 rows x 8 columns]

# %%
#Visualising passenger_count again to cross-check
final_pass_count['passenger_count'].value_counts()
# Out:
# 1    37560913
# 2     8022344
# 5     3848449
# 3     2386087
# 4     1156834
# 6     1153482
# 9          21
# 7          13
# 8           7
# Name: passenger_count, dtype: int64

# %%
#Plotting a Countplot
sb.set_theme(style="darkgrid")
ax = sb.countplot(x="passenger_count",data=final_pass_count)

# %% [markdown]
# ### Cheking if the label has any Negative Values

# %%
final_fare_amt = final_pass_count.copy()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
#checking if there is any negative value in fare_amt
(final_fare_amt['fare_amount'] < 0).any()
# Out:
# True

# %%
final_fare_amt.to_csv('D:\ML Files\checkpoint-1.csv', index=False)

# %% [markdown]
# Therefore, there are negative values in the label, which are illogical.

# %% [markdown]
# # Checkpoint 1

# %%
final_fare_amt = pd.read_csv('D:\ML Files\checkpoint-1.csv')

# %%
negative_rows = final_fare_amt[final_fare_amt['fare_amount'] < 0]
#negative_rows

# %%
negative_rows_idx = list(negative_rows.index)
#negative_rows_idx

# %%
#looking at a specific row 
final_fare_amt.iloc[negative_rows_idx[0]]
# Out:
# key                  2010-03-09 23:37:10.0000005
# fare_amount                                 -2.9
# pickup_datetime          2010-03-09 23:37:10 UTC
# pickup_longitude                       -73.78945
# pickup_latitude                        40.643498
# dropoff_longitude                     -73.788665
# dropoff_latitude                       40.641952
# passenger_count                                1
# Name: 1992, dtype: object

# %%
#dropping the rows
final_fare_amt.drop(axis=0, index=negative_rows_idx,inplace=True)

#resetting the index
final_fare_amt.reset_index(inplace=True)

#final_fare_amt

# %%
#Dropping unnecessary columns from the df 
final_fare_amt.drop(['index'], axis = 1, inplace=True)
final_fare_amt
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 0           2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1           2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2          2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3           2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4         2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                                 ...          ...                      ...
# 54125939   2014-03-15 03:28:00.00000070         14.0  2014-03-15 03:28:00 UTC
# 54125940    2009-03-24 20:46:20.0000002          4.2  2009-03-24 20:46:20 UTC
# 54125941    2011-04-02 22:04:24.0000004         14.1  2011-04-02 22:04:24 UTC
# 54125942    2011-10-26 05:57:51.0000002         28.9  2011-10-26 05:57:51 UTC
# 54125943   2014-12-12 11:33:00.00000015          7.5  2014-12-12 11:33:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54125939        -74.005272        40.740027         -73.963280
# 54125940        -73.957784        40.765530         -73.951640
# 54125941        -73.970505        40.752325         -73.960537
# 54125942        -73.980901        40.764629         -73.870605
# 54125943        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count
# 0                40.712278                1
# 1                40.782004                1
# 2                40.750562                2
# 3                40.758092                1
# 4                40.783762                1
# ...                    ...              ...
# 54125939         40.762555                1
# 54125940         40.773959                1
# 54125941         40.797342                1
# 54125942         40.773963                1
# 54125943         40.783313                1
#
# [54125944 rows x 8 columns]

# %%
#cross-checking if there is any negative value in fare_amt
(final_fare_amt['fare_amount'] < 0).any()
# Out:
# False

# %% [markdown]
# ### Creation of New Features

# %%
import datetime as dt
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
datetime_list = []
for datetime_str in final_fare_amt['pickup_datetime']:
    datetime_value = dt.datetime.strptime(datetime_str, '%Y-%m-%d %H:%M:%S UTC')
    date = datetime_value.date() 
    time = datetime_value.time()
    day = datetime_value.weekday()
    weekend = (day>=4)
    datetime_list.append([date,time,day,weekend])
    #print(date)

# %%
date_series = pd.Series(v[0] for v in datetime_list)
time_series = pd.Series(v[1] for v in datetime_list)
day_series = pd.Series(v[2] for v in datetime_list)
weekend_series = pd.Series(v[3] for v in datetime_list)

# %%
cal = calendar()
holidays = cal.holidays(start= date_series.min(), end=date_series.max())
holidays = [x.date() for x in holidays]
print("Earliest Date in Train Datatset:",date_series.min())
print("Latest Date in Train Dataset:",date_series.max())
# Out:
# Earliest Date in Train Datatset: 2009-01-01
# Latest Date in Train Dataset: 2015-06-30

# %%
holiday_list = []
for date in date_series: 
    if date in holidays:
        holiday_list.append(int(1))
    else: 
        holiday_list.append(int(0))   
holiday_series = pd.Series(v for v in holiday_list)

# %%
holiday = new_combined[new_combined["holiday"] == 1 ]

# %%
holiday.head(25)
# Out:
#      index                            key  fare_amount  \
# 53      53   2010-05-31 18:06:00.00000097        34.67
# 59      59   2012-01-02 14:54:00.00000078         4.90
# 177    177  2009-09-07 18:52:00.000000158         8.10
# 210    210    2015-05-25 15:11:09.0000006        11.00
# 275    275  2013-01-01 14:26:00.000000162         9.00
# 306    306    2011-11-24 01:58:25.0000001        20.50
# 338    338   2014-01-01 05:22:00.00000048         5.00
# 423    423   2010-11-11 21:18:00.00000079         8.90
# 434    434    2015-02-16 17:12:44.0000005         6.00
# 440    440   2010-11-25 22:54:00.00000017        11.30
# 462    462    2011-10-10 18:31:34.0000002         6.10
# 550    550    2010-12-24 19:14:07.0000002         9.70
# 606    606   2009-11-26 18:36:00.00000055         5.30
# 616    616    2013-01-21 19:08:58.0000002         4.50
# 629    629    2012-11-12 17:59:46.0000003        15.50
# 643    643   2010-12-24 22:34:00.00000037         8.90
# 727    727   2011-10-10 07:32:00.00000027        11.30
# 774    774    2009-02-16 07:40:14.0000002        14.50
# 800    800   2009-11-26 03:52:00.00000042         6.50
# 827    827  2010-11-25 00:41:00.000000125         6.10
# 838    838    2011-11-11 04:06:20.0000003         9.70
# 843    843    2011-11-24 04:23:08.0000002         4.90
# 881    881   2009-01-19 10:38:00.00000050         3.70
# 925    925   2014-05-26 21:35:00.00000041         8.50
# 959    959   2012-05-28 19:31:00.00000038         5.70
#
#              pickup_datetime  pickup_longitude  pickup_latitude  \
# 53   2010-05-31 18:06:00 UTC        -73.985427        40.758853
# 440  22:54:00    3    False        1
# 462  18:31:34    0    False        1
# 550  19:14:07    4     True        1
# 606  18:36:00    3    False        1
# 616  19:08:58    0    False        1
# 629  17:59:46    0    False        1
# 643  22:34:00    4     True        1
# 727  07:32:00    0    False        1
# 774  07:40:14    0    False        1
# 800  03:52:00    3    False        1
# 827  00:41:00    3    False        1
# 838  04:06:20    4     True        1
# 843  04:23:08    3    False        1
# 881  10:38:00    0    False        1
# 925  21:35:00    0    False        1
# 959  19:31:00    0    False        1

# %%
new_combined = final_fare_amt.copy()
new_combined = new_combined.reset_index()
# Out:
# False

# %%
new_combined['date'] = date_series
new_combined['time'] = time_series
new_combined['day'] = day_series
new_combined['weekend'] = weekend_series
new_combined['holiday'] = holiday_series

# %%
new_combined.head(25)
# Out:
#     index                            key  fare_amount  \
# 0       0    2009-06-15 17:26:21.0000001          4.5
# 1       1    2010-01-05 16:52:16.0000002         16.9
# 2       2   2011-08-18 00:35:00.00000049          5.7
# 3       3    2012-04-21 04:30:42.0000001          7.7
# 4       4  2010-03-09 07:51:00.000000135          5.3
# 5       5    2011-01-06 09:50:45.0000002         12.1
# 6       6    2012-11-20 20:35:00.0000001          7.5
# 7       7   2012-01-04 17:22:00.00000081         16.5
# 8       8  2012-12-03 13:10:00.000000125          9.0
# 9       9   2009-09-02 01:11:00.00000083          8.9
# 10     10    2012-04-08 07:30:50.0000002          5.3
# 11     11    2009-11-06 01:04:03.0000002          4.1
# 12     12  2013-07-02 19:54:00.000000232          7.0
# 13     13    2011-04-05 17:11:05.0000001          7.7
# 14     14   2014-02-19 07:22:00.00000074         12.5
# 15     15  2009-07-22 16:08:00.000000163          5.3
# 16     16   2010-07-07 14:52:00.00000044          5.3
# 17     17    2014-12-06 20:36:22.0000008          4.0
# 18     18  2010-09-07 13:18:00.000000175         10.5
# 19     19    2013-02-12 12:15:46.0000002         11.5
# 20     20    2009-08-06 18:17:23.0000001          4.5
# 21     21  2010-12-06 12:29:00.000000199          4.9
# 22     22   2009-12-10 15:37:00.00000020          6.1
# 23     23   2011-06-21 16:15:00.00000073          7.3
# 24     24  2011-06-28 19:47:00.000000168          4.5
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0   2009-06-15 17:26:21 UTC        -73.844311        40.721319
# 1   2010-01-05 16:52:16 UTC        -74.016048        40.711303
# 2   2011-08-18 00:35:00 UTC        -73.982738        40.761270
# 3   2012-04-21 04:30:42 UTC        -73.987130        40.733143
# 4   2010-03-09 07:51:00 UTC        -73.968095        40.768008
# 5   2011-01-06 09:50:45 UTC        -74.000964        40.731630
# 6   2012-11-20 20:35:00 UTC        -73.980002        40.751662
# 7   2012-01-04 17:22:00 UTC        -73.951300        40.774138
# 8   2012-12-03 13:10:00 UTC        -74.006462        40.726713
# 9   2009-09-02 01:11:00 UTC        -73.980658        40.733873
# 10  2012-04-08 07:30:50 UTC        -73.996335        40.737142
# 11  2009-11-06 01:04:03 UTC        -73.991601        40.744712
# 12  2013-07-02 19:54:00 UTC        -74.005360        40.728867
# 3                3    2012-04-21 04:30:42.0000001          7.7
# 4                4  2010-03-09 07:51:00.000000135          5.3
# ...            ...                            ...          ...
# 54125939  54125939   2014-03-15 03:28:00.00000070         14.0
# 54125940  54125940    2009-03-24 20:46:20.0000002          4.2
# 54125941  54125941    2011-04-02 22:04:24.0000004         14.1
# 54125942  54125942    2011-10-26 05:57:51.0000002         28.9
# 54125943  54125943   2014-12-12 11:33:00.00000015          7.5
#
#                   pickup_datetime  pickup_longitude  pickup_latitude  \
# 0         2009-06-15 17:26:21 UTC        -73.844311        40.721319
# 1         2010-01-05 16:52:16 UTC        -74.016048        40.711303
# 2         2011-08-18 00:35:00 UTC        -73.982738        40.761270
# 3         2012-04-21 04:30:42 UTC        -73.987130        40.733143
# 4         2010-03-09 07:51:00 UTC        -73.968095        40.768008
# ...                           ...               ...              ...
# 54125939  2014-03-15 03:28:00 UTC        -74.005272        40.740027
# 54125940  2009-03-24 20:46:20 UTC        -73.957784        40.765530
# 54125941  2011-04-02 22:04:24 UTC        -73.970505        40.752325
# 54125942  2011-10-26 05:57:51 UTC        -73.980901        40.764629
# 54125943  2014-12-12 11:33:00 UTC        -73.969722        40.797668
#
#           dropoff_longitude  dropoff_latitude  passenger_count        date  \
# 0                -73.841610         40.712278                1  2009-06-15
# 1                -73.979268         40.782004                1  2010-01-05
# 2                -73.991242         40.750562                2  2011-08-18
# 3                -73.991567         40.758092                1  2012-04-21
# 4                -73.956655         40.783762                1  2010-03-09
# ...                     ...               ...              ...         ...
# 54125939         -73.963280         40.762555                1  2014-03-15
# 54125940         -73.951640         40.773959                1  2009-03-24
# 54125941         -73.960537         40.797342                1  2011-04-02
# 54125942         -73.870605         40.773963                1  2011-10-26
# 54125943         -73.970885         40.783313                1  2014-12-12
#
#               time  day  weekend  holiday
# 0         17:26:21    0    False        0
# 1         16:52:16    1    False        0
# 2         00:35:00    3    False        0
# 3         04:30:42    5     True        0
# 4         07:51:00    1    False        0
# ...            ...  ...      ...      ...
# 54125939  03:28:00    5     True        0
# 54125940  20:46:20    1    False        0
# 54125941  22:04:24    5     True        0
# 54125942  05:57:51    2    False        0
# 54125943  11:33:00    4     True        0
#
# [54125944 rows x 14 columns]

# %%
new_combined.to_csv('D:\ML Files\checkpoint-2.csv', index=False)

# %% [markdown]
# # Checkpoint 2

# %%
new_combined = pd.read_csv('D:\ML Files\checkpoint-2.csv')

# %%
new_combined.head(25)

# %%
new_combined.isnull().values.any()

# %% [markdown]
# ### Dropping pickup date time, key and index

# %%
new_combined.drop(columns=['key','pickup_datetime','index'])
# Out:
#           fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                 4.5        -73.844311        40.721319         -73.841610
# 1                16.9        -74.016048        40.711303         -73.979268
# 2                 5.7        -73.982738        40.761270         -73.991242
# 3                 7.7        -73.987130        40.733143         -73.991567
# 4                 5.3        -73.968095        40.768008         -73.956655
# ...               ...               ...              ...                ...
# 54125939         14.0        -74.005272        40.740027         -73.963280
# 54125940          4.2        -73.957784        40.765530         -73.951640
# 54125941         14.1        -73.970505        40.752325         -73.960537
# 54125942         28.9        -73.980901        40.764629         -73.870605
# 54125943          7.5        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count        date      time  day  \
# 0                40.712278                1  2009-06-15  17:26:21    0
# 1                40.782004                1  2010-01-05  16:52:16    1
# 2                40.750562                2  2011-08-18  00:35:00    3
# 3                40.758092                1  2012-04-21  04:30:42    5
# 4                40.783762                1  2010-03-09  07:51:00    1
# ...                    ...              ...         ...       ...  ...
# 54125939         40.762555                1  2014-03-15  03:28:00    5
# 54125940         40.773959                1  2009-03-24  20:46:20    1
# 54125941         40.797342                1  2011-04-02  22:04:24    5
# 54125942         40.773963                1  2011-10-26  05:57:51    2
# 54125943         40.783313                1  2014-12-12  11:33:00    4
#
#           weekend  holiday
# 0           False        0
# 1           False        0
# 2           False        0
# 3            True        0
# 4           False        0
# ...           ...      ...
# 54125939     True        0
# 54125940    False        0
# 54125941     True        0
# 54125942    False        0
# 54125943     True        0
#
# [54125944 rows x 11 columns]

# %% [markdown]
# ### Checking peak hour if pickup time is a peak hour

# %%
peak_hour_df= new_combined[['time','day']]
peak_hour_df
# Out:
#               time  day
# 0         17:26:21    0
# 1         16:52:16    1
# 2         00:35:00    3
# 3         04:30:42    5
# 4         07:51:00    1
# ...            ...  ...
# 54125939  03:28:00    5
# 54125940  20:46:20    1
# 54125941  22:04:24    5
# 54125942  05:57:51    2
# 54125943  11:33:00    4
#
# [54125944 rows x 2 columns]

# %%
# Initalise peak hour timings
def in_between(now, start, end):
    if start <= end:
        return start < now <= end
    else: # over midnight e.g., 23:30-04:15
        return start < now or now <= end
    
    
morning_from = dt.time(7,0,0)
morning_till = dt.time(9,0,0)

evening_from = dt.time(15,0,0)
evening_till = dt.time(19,0,0)

evening_from_fri = dt.time(14,0,0)

peak_hour_list = []
for index, row in peak_hour_df.iterrows():
    time = dt.datetime.strptime(row['time'], '%H:%M:%S').time() 
    
    # If day is Mon - Thur ------------
    if 0 <= row['day'] <= 3:
        if in_between(time, morning_from, morning_till) or in_between(time, evening_from, evening_till):
            peak_hour_list.append(int(1))
        else:
            peak_hour_list.append(int(0))
    # If day is Friday -----------------
    
    elif row['day'] == 4: 
        if in_between(time, morning_from, morning_till) or in_between(time, evening_from_fri, evening_till):
            peak_hour_list.append(int(1))
        else:
            peak_hour_list.append(int(0))
    # If day is Sat - Sun 
    else: 
        peak_hour_list.append(int(0))

# %%
peak_hour_series = pd.Series(v for v in peak_hour_list)

# %%
peak_hour_df.drop(columns='peak_hour')
# Out:
#               time  day
# 0         17:26:21    0
# 1         16:52:16    1
# 2         00:35:00    3
# 3         04:30:42    5
# 4         07:51:00    1
# ...            ...  ...
# 54125939  03:28:00    5
# 54125940  20:46:20    1
# 54125941  22:04:24    5
# 54125942  05:57:51    2
# 54125943  11:33:00    4
#
# [54125944 rows x 2 columns]

# %%
new_combined['peak_hour'] = peak_hour_series

# %%
new_combined.head(20)
# Out:
#     index                            key  fare_amount  \
# 0       0    2009-06-15 17:26:21.0000001          4.5
# 1       1    2010-01-05 16:52:16.0000002         16.9
# 2       2   2011-08-18 00:35:00.00000049          5.7
# 3       3    2012-04-21 04:30:42.0000001          7.7
# 4       4  2010-03-09 07:51:00.000000135          5.3
# 19         -73.961250         40.758787                1  2013-02-12
#
#         time  day  weekend  holiday  peak_hour
# 0   17:26:21    0    False        0          1
# 1   16:52:16    1    False        0          1
# 2   00:35:00    3    False        0          0
# 3   04:30:42    5     True        0          0
# 4   07:51:00    1    False        0          1
# 5   09:50:45    3    False        0          0
# 6   20:35:00    1    False        0          0
# 7   17:22:00    2    False        0          1
# 8   13:10:00    0    False        0          0
# 9   01:11:00    2    False        0          0
# 10  07:30:50    6     True        0          0
# 11  01:04:03    4     True        0          0
# 12  19:54:00    1    False        0          0
# 13  17:11:05    1    False        0          1
# 14  07:22:00    2    False        0          1
# 15  16:08:00    2    False        0          1
# 16  14:52:00    2    False        0          0
# 17  20:36:22    5     True        0          0
# 18  13:18:00    1    False        0          0
# 19  12:15:46    1    False        0          0

# %%
checkpoint3 = new_combined.drop(columns=['key','pickup_datetime','index','date'])
checkpoint3
# Out:
#           fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                 4.5        -73.844311        40.721319         -73.841610
# 1                16.9        -74.016048        40.711303         -73.979268
# 2                 5.7        -73.982738        40.761270         -73.991242
# 3                 7.7        -73.987130        40.733143         -73.991567
# 4                 5.3        -73.968095        40.768008         -73.956655
# ...               ...               ...              ...                ...
# 54125939         14.0        -74.005272        40.740027         -73.963280
# 54125940          4.2        -73.957784        40.765530         -73.951640
# 54125941         14.1        -73.970505        40.752325         -73.960537
# 54125942         28.9        -73.980901        40.764629         -73.870605
# 54125943          7.5        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count      time  day  weekend  holiday  \
# 0                40.712278                1  17:26:21    0    False        0
# 1                40.782004                1  16:52:16    1    False        0
# 2                40.750562                2  00:35:00    3    False        0
# 3                40.758092                1  04:30:42    5     True        0
# 4                40.783762                1  07:51:00    1    False        0
# ...                    ...              ...       ...  ...      ...      ...
# 54125939         40.762555                1  03:28:00    5     True        0
# 54125940         40.773959                1  20:46:20    1    False        0
# 54125941         40.797342                1  22:04:24    5     True        0
# 54125942         40.773963                1  05:57:51    2    False        0
# 54125943         40.783313                1  11:33:00    4     True        0
#
#           peak_hour
# 0                 1
# 1                 1
# 2                 0
# 3                 0
# 4                 1
# ...             ...
# 54125939          0
# 54125940          0
# 54125941          0
# 54125942          0
# 54125943          0
#
# [54125944 rows x 11 columns]

# %% [markdown]
# # Checkpoint 3

# %%
checkpoint3.to_csv('D:\ML Files\checkpoint-3.csv', index=False)

# %%
new_combined = pd.read_csv('D:\ML Files\checkpoint-3.csv')

# %%
hot_dist_df = new_combined[['pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude']]

# %% [markdown]
# ## Hotspot or not?

# %%
hotspot_json = pd.read_json('hotspot_location.json')
hotspot_json
# Out:
#                   times_square            grand_central  \
# area1   [40.76246, -73.989779]  [40.756996, -73.978261]
# area2  [40.753007, -73.979601]  [40.748831, -73.973815]
#
#                                memorial              rockefeller  \
# area1           [40.715161, -74.015973]  [40.761666, -73.982854]
# area2  [40.708709999999996, -74.010904]  [40.757262, -73.978071]
#
#                   union_square             central_park  \
# area1   [40.73978, -73.995001]  [40.792898, -73.967833]
# area2  [40.731591, -73.986553]  [40.771863, -73.963416]
#
#                           soho                 highline  \
# area1   [40.722215, -74.00072]  [40.749751, -74.007163]
# area2  [40.718183, -73.997963]  [40.744284, -74.001868]
#
#                       tompkins          brooklyn_museum
# area1  [40.728263, -73.983154]   [40.675063, -73.96672]
# area2  [40.724239, -73.981092]  [40.670381, -73.962357]

# %%
# Latitude is the 40.721319 (Positive number) while longitude is the negative number
def within_area(given_lon, given_lat,one_lon,one_lat,two_lon, two_lat):
    if one_lon <= given_lon <= two_lon and one_lat >= given_lat >= two_lat: 
        return True
    else: 
        return False

# %%
hotspot_list = []
for index, row in hot_dist_df.iterrows():
    for x in hotspot_json.keys(): 
        if within_area(row['pickup_longitude'], row['pickup_latitude'], hotspot_json[x]['area1'][1], hotspot_json[x]['area1'][0], hotspot_json[x]['area2'][1], hotspot_json[x]['area2'][0]) or within_area(row['dropoff_longitude'], row['dropoff_latitude'], hotspot_json[x]['area1'][1], hotspot_json[x]['area1'][0], hotspot_json[x]['area2'][1], hotspot_json[x]['area2'][0]):
            hotspot = int(1)
            break
        else: 
            hotspot = int(0)
            
    hotspot_list.append(hotspot)

# %%
hotspot_series = pd.Series(v for v in hotspot_list)
hotspot_series
# Out:
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0
#            ..
# 54125939    0
# 54125940    0
# 54125941    0
# 54125942    0
# 54125943    0
# Length: 54125944, dtype: int64

# %%
hotspot_series.value_counts()
# Out:
# 0    41271281
# 1    12854663
# dtype: int64

# %%
new_combined['hotspot'] = hotspot_series

# %%
new_combined
# Out:
#           fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                 4.5        -73.844311        40.721319         -73.841610
# 1                16.9        -74.016048        40.711303         -73.979268
# 2                 5.7        -73.982738        40.761270         -73.991242
# 3                 7.7        -73.987130        40.733143         -73.991567
# 4                 5.3        -73.968095        40.768008         -73.956655
# ...               ...               ...              ...                ...
# 54125939         14.0        -74.005272        40.740027         -73.963280
# 54125940          4.2        -73.957784        40.765530         -73.951640
# 54125941         14.1        -73.970505        40.752325         -73.960537
# 54125942         28.9        -73.980901        40.764629         -73.870605
# 54125943          7.5        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count      time  day  weekend  holiday  \
# 0                40.712278                1  17:26:21    0    False        0
# 1                40.782004                1  16:52:16    1    False        0
# 2                40.750562                2  00:35:00    3    False        0
# 3                40.758092                1  04:30:42    5     True        0
# 4                40.783762                1  07:51:00    1    False        0
# ...                    ...              ...       ...  ...      ...      ...
# 54125939         40.762555                1  03:28:00    5     True        0
# 54125940         40.773959                1  20:46:20    1    False        0
# 54125941         40.797342                1  22:04:24    5     True        0
# 54125942         40.773963                1  05:57:51    2    False        0
# 54125943         40.783313                1  11:33:00    4     True        0
#
#           peak_hour  hotspot
# 0                 1        0
# 1                 1        0
# 2                 0        1
# 3                 0        1
# 4                 1        0
# ...             ...      ...
# 54125939          0        0
# 54125940          0        0
# 54125941          0        0
# 54125942          0        0
# 54125943          0        0
#
# [54125944 rows x 12 columns]

# %%
new_combined.to_csv('D:\ML Files\checkpoint-4-v3.csv', index=False)

# %%
hotspot_true_df = new_combined[new_combined['hotspot']==1]

# %%
hotspot_true_df
# Out:
#           fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 2                 5.7        -73.982738        40.761270         -73.991242
# 3                 7.7        -73.987130        40.733143         -73.991567
# 8                 9.0        -74.006462        40.726713         -73.993078
# 14               12.5        -73.986430        40.760465         -73.988990
# 22                6.1        -73.969622        40.756973         -73.981152
# ...               ...               ...              ...                ...
# 54125928          8.0        -73.990037        40.738550         -73.990343
# 54125929          6.5        -73.989768        40.739100         -73.986871
# 54125932         18.0        -73.987335        40.755325         -74.015221
# 54125933          5.3        -73.976189        40.748318         -73.979680
# 54125935          6.1        -73.990946        40.736619         -73.992298
#
#           dropoff_latitude  passenger_count      time  day  weekend  holiday  \
# 2                40.750562                2  00:35:00    3    False        0
# 3                40.758092                1  04:30:42    5     True        0
# 8                40.731628                1  13:10:00    0    False        0
# 14               40.737075                1  07:22:00    2    False        0
# 22               40.759712                1  15:37:00    3    False        0
# ...                    ...              ...       ...  ...      ...      ...
# 54125928         40.746462                1  17:30:00    4     True        0
# 54125929         40.751651                1  07:36:20    4     True        0
# 54125932         40.710213                2  20:45:19    5     True        0
# 54125933         40.757659                1  20:16:35    2    False        0
# 54125935         40.740316                3  00:46:43    4     True        0
#
#           peak_hour  hotspot
# 2                 0        1
# 3                 0        1
# 8                 0        1
# 14                1        1
# 22                1        1
# ...             ...      ...
# 54125928          1        1
# 54125929          1        1
# 54125932          0        1
# 54125933          0        1
# 54125935          0        1
#
# [12854663 rows x 12 columns]

# %%
new_combined.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Calculating distance

# %%
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles. Determines return value units.
    return c * r

# %%
dist_list = []
for index, row in hot_dist_df.iterrows():
    dist = haversine(row['pickup_longitude'], row['pickup_latitude'],row['dropoff_longitude'],row['dropoff_latitude'])
    dist_list.append(dist)

# %%
dist_series = pd.Series(v for v in dist_list)
dist_series
# Out:
# 0           1.030764
# 1           8.450134
# 2           1.389525
# 3           2.799270
# 4           1.999157
#               ...
# 54125939    4.334397
# 54125940    1.070590
# 54125941    5.075548
# 54125942    9.346157
# 54125943    1.599203
# Length: 54125944, dtype: float64

# %%
new_combined['dist'] = dist_series

# %%
dist_cost = new_combined[['dist', 'fare_amount']]
dist_cost.plot(x='dist', y= 'fare_amount', kind='scatter', figsize = (10,6), title = 'Distance and Fare amount in NYC')
# Out:
# <AxesSubplot:title={'center':'Distance and Fare amount in NYC'}, xlabel='dist', ylabel='fare_amount'>

# %%
dist_cost = dist_cost[dist_cost['fare_amount']<1000]
dist_cost.plot(x='dist', y= 'fare_amount', kind='scatter', figsize = (10,6), title = 'Distance and Fare amount in NYC')
# Out:
# <AxesSubplot:title={'center':'Distance and Fare amount in NYC'}, xlabel='dist', ylabel='fare_amount'>

# %%
new_combined
# Out:
#           fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                 4.5        -73.844311        40.721319         -73.841610
# 1                16.9        -74.016048        40.711303         -73.979268
# 2                 5.7        -73.982738        40.761270         -73.991242
# 3                 7.7        -73.987130        40.733143         -73.991567
# 4                 5.3        -73.968095        40.768008         -73.956655
# ...               ...               ...              ...                ...
# 54125939         14.0        -74.005272        40.740027         -73.963280
# 54125940          4.2        -73.957784        40.765530         -73.951640
# 54125941         14.1        -73.970505        40.752325         -73.960537
# 54125942         28.9        -73.980901        40.764629         -73.870605
# 54125943          7.5        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count      time  day  weekend  holiday  \
# 0                40.712278                1  17:26:21    0    False        0
# 1                40.782004                1  16:52:16    1    False        0
# 2                40.750562                2  00:35:00    3    False        0
# 3                40.758092                1  04:30:42    5     True        0
# 4                40.783762                1  07:51:00    1    False        0
# ...                    ...              ...       ...  ...      ...      ...
# 54125939         40.762555                1  03:28:00    5     True        0
# 54125940         40.773959                1  20:46:20    1    False        0
# 54125941         40.797342                1  22:04:24    5     True        0
# 54125942         40.773963                1  05:57:51    2    False        0
# 54125943         40.783313                1  11:33:00    4     True        0
#
#           peak_hour  hotspot      dist
# 0                 1        0  1.030764
# 1                 1        0  8.450134
# 2                 0        1  1.389525
# 3                 0        1  2.799270
# 4                 1        0  1.999157
# ...             ...      ...       ...
# 54125939          0        0  4.334397
# 54125940          0        0  1.070590
# 54125941          0        0  5.075548
# 54125942          0        0  9.346157
# 54125943          0        0  1.599203
#
# [54125944 rows x 13 columns]

# %%
new_combined.to_csv('D:\ML Files\checkpoint-5.csv', index=False)
