# %% [markdown]
# # Running Neural Networks with Traffic

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
model = tf.keras.models.load_model('NN_traffic_density_v2.h5')
model

# %%
checkpoint5_traffic = pd.read_csv('../checkpoint5_traffic.csv')
checkpoint5_traffic
# Out:
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54125939        -74.005272        40.740027         -73.963280
# 54125940        -73.957784        40.765530         -73.951640
# 54125941        -73.970505        40.752325         -73.960537
# 54125942        -73.980901        40.764629         -73.870605
# 54125943        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count      time  day  weekend  holiday  \
# 0                40.712278                1  17:26:21    0        0        0
# ...

# %%
labels = checkpoint5_traffic[['fare_amount']]
labels
# Out:
#           fare_amount
# 0                 4.5
# 1                16.9
# 2                 5.7
# 3                 7.7
# 4                 5.3
# ...               ...
# 54125939         14.0
# 54125940          4.2
# 54125941         14.1
# 54125942         28.9
# 54125943          7.5
#
# [54125944 rows x 1 columns]

# %%
del checkpoint5_traffic['fare_amount']
checkpoint5_traffic
# Out:
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54125939        -74.005272        40.740027         -73.963280
# 54125940        -73.957784        40.765530         -73.951640
# 54125941        -73.970505        40.752325         -73.960537
# 54125942        -73.980901        40.764629         -73.870605
# 54125943        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count      time  day  weekend  holiday  \
# 0                40.712278                1  17:26:21    0        0        0
# ...

# %%
del checkpoint5_traffic['time']
checkpoint5_traffic
# Out:
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54125939        -74.005272        40.740027         -73.963280
# 54125940        -73.957784        40.765530         -73.951640
# 54125941        -73.970505        40.752325         -73.960537
# 54125942        -73.980901        40.764629         -73.870605
# 54125943        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count  day  weekend  holiday  peak_hour  \
# 0                40.712278                1    0        0        0          1
# ...

# %%
sc = StandardScaler()
checkpoint_5_scaled = np.array(sc.fit_transform(checkpoint5_traffic))
labels_scaled = np.array(labels)
print("successfully scaled...")
# Out:
# successfully scaled...

# %%
print("splitting...")
#splitting data into train test 
X_train, X_test, y_train, y_test = train_test_split(checkpoint_5_scaled, labels_scaled, test_size=0.2, random_state=42)
# Out:
# splitting...

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (43300755, 12)
# y_train shape: (43300755, 1)
# X_test shape: (10825189, 12)
# y_test shape: (10825189, 1)

# %% [markdown]
# ### Testing on kaggle dataset

# %%
print("Reading Datafile...")
test_set = pd.read_csv('../kaggle_test_traffic.csv')
print("Success!")
# Out:
# Reading Datafile...
# Success!

# %%
test_key_series = test_set['key'].squeeze()
del test_set['key']

# %%
test_set
# Out:
#       pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0           -73.973320        40.763805         -73.981430         40.743835
# 1           -73.986862        40.719383         -73.998886         40.739201
# 2           -73.982524        40.751260         -73.979654         40.746139
# 3           -73.981160        40.767807         -73.990448         40.751635
# 4           -73.966046        40.789775         -73.988565         40.744427
# ...                ...              ...                ...               ...
# 9909        -73.968124        40.796997         -73.955643         40.780388
# 9910        -73.945511        40.803600         -73.960213         40.776371
# 9911        -73.991600        40.726608         -73.789742         40.647011
# 9912        -73.985573        40.735432         -73.939178         40.801731
# 9913        -73.988022        40.754070         -74.000282         40.759220
#
# ...

# %%
test_set_scaled = np.array(sc.transform(test_set))

# %%
# make a prediction
y_pred = model.predict_on_batch(test_set_scaled)
# show the inputs and predicted outputs

# %%
y_pred
# Out:
# array([[ 9.252579],
#        [ 9.252579],
#        [ 9.252579],
#        ...,
#        [49.606087],
#        [ 9.252579],
#        [ 9.252579]], dtype=float32)

# %%
y_pred = y_pred.flatten()

# %%
new_y_pred= []
for a in y_pred: 
    new_value = float("%.2f" % a)
    new_y_pred.append(new_value)
y_pred_series = pd.Series(new_y_pred)
df = pd.DataFrame({'key': test_key_series,'fare_amount': new_y_pred})
df
# Out:
#                               key  fare_amount
# 0     2015-01-27 13:08:24.0000002         9.25
# 1     2015-01-27 13:08:24.0000003         9.25
# 2     2011-10-08 11:53:44.0000002         9.25
# 3     2012-12-01 21:12:12.0000002         9.25
# 4     2012-12-01 21:12:12.0000003         9.25
# ...                           ...          ...
# 9909  2015-05-10 12:37:51.0000002         9.25
# 9910  2015-01-12 17:05:51.0000001         9.25
# 9911  2015-04-19 20:44:15.0000001        49.61
# 9912  2015-01-31 01:05:19.0000005         9.25
# 9913  2015-01-18 14:06:23.0000006         9.25
#
# [9914 rows x 2 columns]

# %%
df.to_csv('NNPrediction_traffic_v2.csv',index=False )
