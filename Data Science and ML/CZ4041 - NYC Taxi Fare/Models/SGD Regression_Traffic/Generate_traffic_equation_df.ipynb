# %% [markdown]
# # Create Dataframe for Traffic Density

# %%
import pandas as pd
import sys

# %%
#importing the checkpoint5
checkpoint5 = pd.read_csv('../checkpoint5_traffic.csv')
checkpoint5
# Out:
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54125939        -74.005272        40.740027         -73.963280
# 54125940        -73.957784        40.765530         -73.951640
# 54125941        -73.970505        40.752325         -73.960537
# 54125942        -73.980901        40.764629         -73.870605
# 54125943        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count      time  day  weekend  holiday  \
# 0                40.712278                1  17:26:21    0        0        0
# 1                40.782004                1  16:52:16    1        0        0
# 2                40.750562                2  00:35:00    3        0        0
# 3                40.758092                1  04:30:42    5        1        0
# 4                40.783762                1  07:51:00    1        0        0
# ...                    ...              ...       ...  ...      ...      ...
# 54125939         40.762555                1  03:28:00    5        1        0
# 54125940         40.773959                1  20:46:20    1        0        0
# 54125941         40.797342                1  22:04:24    5        1        0
# 54125942         40.773963                1  05:57:51    2        0        0
# 54125943         40.783313                1  11:33:00    4        1        0
#
#           peak_hour  hotspot      dist  fare_amount  traffic_density
# 0                 1        0  1.030764          4.5         0.383333
# 1                 1        0  8.450134         16.9         0.383333
# 2                 0        1  1.389525          5.7         0.383333
# 3                 0        1  2.799270          7.7         0.700000
# 4                 1        0  1.999157          5.3         0.383333
# ...             ...      ...       ...          ...              ...
# 54125939          0        0  4.334397         14.0         0.400000
# 54125940          0        0  1.070590          4.2         0.083333
# 54125941          0        0  5.075548         14.1         0.400000
# 54125942          0        0  9.346157         28.9         0.083333
# 54125943          0        0  1.599203          7.5         0.400000
#
# [54125944 rows x 14 columns]

# %%
traffic_labels = checkpoint5[['traffic_density']]
traffic_labels
# Out:
#           traffic_density
# 0                0.383333
# 1                0.383333
# 2                0.383333
# 3                0.700000
# 4                0.383333
# ...                   ...
# 54125939         0.400000
# 54125940         0.083333
# 54125941         0.400000
# 54125942         0.083333
# 54125943         0.400000
#
# [54125944 rows x 1 columns]

# %%
#Getting the summary of the dataset
shape = checkpoint5.shape

NUM_ROWS = shape[0]
NUM_COLS = shape[1]

print("Number of Rows:", NUM_ROWS)
print("NUmber of Columns:", NUM_COLS)
# Out:
# Number of Rows: 54125944
# NUmber of Columns: 14

# %%
#converting the weekend column from boolean to binary
checkpoint5.replace({False: 0, True: 1}, inplace=True)
checkpoint5
# Out:
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -73.844311        40.721319         -73.841610
# 1               -74.016048        40.711303         -73.979268
# 2               -73.982738        40.761270         -73.991242
# 3               -73.987130        40.733143         -73.991567
# 4               -73.968095        40.768008         -73.956655
# ...                    ...              ...                ...
# 54125939        -74.005272        40.740027         -73.963280
# 54125940        -73.957784        40.765530         -73.951640
# 54125941        -73.970505        40.752325         -73.960537
# 54125942        -73.980901        40.764629         -73.870605
# 54125943        -73.969722        40.797668         -73.970885
#
#           dropoff_latitude  passenger_count      time  day  weekend  holiday  \
# 0                40.712278                1  17:26:21    0        0        0
# 1                40.782004                1  16:52:16    1        0        0
# 2                40.750562                2  00:35:00    3        0        0
# 3                40.758092                1  04:30:42    5        1        0
# 4                40.783762                1  07:51:00    1        0        0
# ...                    ...              ...       ...  ...      ...      ...
# 54125939         40.762555                1  03:28:00    5        1        0
# 54125940         40.773959                1  20:46:20    1        0        0
# 54125941         40.797342                1  22:04:24    5        1        0
# 54125942         40.773963                1  05:57:51    2        0        0
# 54125943         40.783313                1  11:33:00    4        1        0
#
#           peak_hour  hotspot      dist  fare_amount  traffic_density
# 0                 1        0  1.030764          4.5         0.383333
# 1                 1        0  8.450134         16.9         0.383333
# 2                 0        1  1.389525          5.7         0.383333
# 3                 0        1  2.799270          7.7         0.700000
# 4                 1        0  1.999157          5.3         0.383333
# ...             ...      ...       ...          ...              ...
# 54125939          0        0  4.334397         14.0         0.400000
# 54125940          0        0  1.070590          4.2         0.083333
# 54125941          0        0  5.075548         14.1         0.400000
# 54125942          0        0  9.346157         28.9         0.083333
# 54125943          0        0  1.599203          7.5         0.400000
#
# [54125944 rows x 14 columns]

# %% [markdown]
#  ### Traffic = A.max(weekend V ph, 0.05 ) + B.max(Time_peak_hr,0.1) + C.max(hotspot, 0.1)  + e(small constant)

# %% [markdown]
# #### Adding Epsilon into the Dataframe

# %%
#initialising EPSILON
EPSILON = sys.float_info.epsilon
EPSILON
# Out:
# 2.220446049250313e-16

# %%
EPSILON_LIST = []
for i in range(NUM_ROWS):
    EPSILON_LIST.append(EPSILON)

print("Length:", len(EPSILON_LIST))
# Out:
# Length: 54125944

# %%
#convert it to df
own_eqn_df = pd.DataFrame(EPSILON_LIST)

# %%
#Renaming the header
own_eqn_df.rename(columns={0:"e"}, inplace=True)
own_eqn_df
# Out:
#                      e
# 0         2.220446e-16
# 1         2.220446e-16
# 2         2.220446e-16
# 3         2.220446e-16
# 4         2.220446e-16
# ...                ...
# 54125939  2.220446e-16
# 54125940  2.220446e-16
# 54125941  2.220446e-16
# 54125942  2.220446e-16
# 54125943  2.220446e-16
#
# [54125944 rows x 1 columns]

# %% [markdown]
# #### Defining Functions for the terms of the Formula

# %%
#First term of the formula
def create_day_feature(weekend, holiday):
    day = max((weekend or holiday), 0.05)
    return day

#Second term of the formula
def create_time_feature(peak_hr):
    time = max(peak_hr, 0.1)
    return time

#Third term of the formula
def create_location_feature(hotspot):
    location = max(hotspot, 0.1)
    return location

# %% [markdown]
# #### Creating the Various Columns

# %%
#Iterating through the dataset
day_list = []
time_list = []
location_list = []

for index, row in checkpoint5.iterrows():
    day_value = create_day_feature(row['weekend'], row['holiday'])
    time_value = create_time_feature(row['peak_hour'])
    location_value = create_location_feature(row['hotspot'])
    
    day_list.insert(index,day_value)
    time_list.insert(index,time_value)
    location_list.insert(index,location_value)

#check 
if len(day_list) == NUM_ROWS:
    print('Successful Creation of day_list!')
if len(time_list) == NUM_ROWS:
    print('Successful Creation of time_list!')
if len(location_list) == NUM_ROWS:
    print('Successful Creation of location_list!')
else:
    print("Failed!")
# Out:
# Successful Creation of day_list!
# Successful Creation of time_list!
# Successful Creation of location_list!

# %%
#Converting the lists into dataframes
day_df = pd.DataFrame(day_list)
time_df = pd.DataFrame(time_list)
location_df = pd.DataFrame(location_list)

# %%
day_df
# Out:
#              0
# 0         0.05
# 1         0.05
# 2         0.05
# 3         1.00
# 4         0.05
# ...        ...
# 54125939  1.00
# 54125940  0.05
# 54125941  1.00
# 54125942  0.05
# 54125943  1.00
#
# [54125944 rows x 1 columns]

# %%
#Joining the Dataframes
# own_eqn_df.join(traffic_labels)
# Out:
#                      e  traffic_density
# 0         2.220446e-16         0.383333
# 1         2.220446e-16         0.383333
# 2         2.220446e-16         0.383333
# 3         2.220446e-16         0.700000
# 4         2.220446e-16         0.383333
# ...                ...              ...
# 54125939  2.220446e-16         0.400000
# 54125940  2.220446e-16         0.083333
# 54125941  2.220446e-16         0.400000
# 54125942  2.220446e-16         0.083333
# 54125943  2.220446e-16         0.400000
#
# [54125944 rows x 2 columns]

# %%
own_eqn_df['day'] = day_df
own_eqn_df['time'] = time_df
own_eqn_df['location'] = location_df

# %%
own_eqn_df['traffic_density'] = traffic_labels

# %%
own_eqn_df
# Out:
#                      e   day  time  location  traffic_density
# 0         2.220446e-16  0.05   1.0       0.1         0.383333
# 1         2.220446e-16  0.05   1.0       0.1         0.383333
# 2         2.220446e-16  0.05   0.1       1.0         0.383333
# 3         2.220446e-16  1.00   0.1       1.0         0.700000
# 4         2.220446e-16  0.05   1.0       0.1         0.383333
# ...                ...   ...   ...       ...              ...
# 54125939  2.220446e-16  1.00   0.1       0.1         0.400000
# 54125940  2.220446e-16  0.05   0.1       0.1         0.083333
# 54125941  2.220446e-16  1.00   0.1       0.1         0.400000
# 54125942  2.220446e-16  0.05   0.1       0.1         0.083333
# 54125943  2.220446e-16  1.00   0.1       0.1         0.400000
#
# [54125944 rows x 5 columns]

# %%
own_eqn_df.to_csv('own_eqn_subdataset.csv',index=False)

# %%
own_eqn_df
# Out:
#                      e   day  time  location  traffic_density
# 0         2.220446e-16  0.05   1.0       0.1         0.383333
# 1         2.220446e-16  0.05   1.0       0.1         0.383333
# 2         2.220446e-16  0.05   0.1       1.0         0.383333
# 3         2.220446e-16  1.00   0.1       1.0         0.700000
# 4         2.220446e-16  0.05   1.0       0.1         0.383333
# ...                ...   ...   ...       ...              ...
# 54125939  2.220446e-16  1.00   0.1       0.1         0.400000
# 54125940  2.220446e-16  0.05   0.1       0.1         0.083333
# 54125941  2.220446e-16  1.00   0.1       0.1         0.400000
# 54125942  2.220446e-16  0.05   0.1       0.1         0.083333
# 54125943  2.220446e-16  1.00   0.1       0.1         0.400000
#
# [54125944 rows x 5 columns]
